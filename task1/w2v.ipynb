# %% [markdown]
# ---
#
# Word2Vec
# -------
#
# ---

# %% [markdown]
# Please, follow this instructions:
# ---
# 1. Define functions and classes in individual cells.
# 2. Do not change our defenition of data preprocessing (downloading, reading and dictionary creation)
# 3. Do not change signatures of our methods and classes
# 4. Make your final assigment clear (do not use prints for debugging stuff)
# 5. And write all your imports in the next cell
#
# May the Force be with you!

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import collections
import math
import os
import random
import zipfile

import numpy as np
from six.moves import urllib
from six.moves import xrange
import tensorflow as tf

from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Step 0: Download the data.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urllib.request.urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified', filename)
    else:
        print(statinfo.st_size)
        raise Exception(
            'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# ### Step 1: Read data.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data

words = read_data(filename)

# %%
print('Data size', len(words))
# Out:
# Data size 17005207

# %% [markdown]
# ### Step 2: Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0    # dictionary['UNK']
            unk_count += 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys()))
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
del words    # Hint to reduce memory.

# %%
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10], [reverse_dictionary[i] for i in data[:10]])
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5237, 3084, 12, 6, 195, 2, 3137, 46, 59, 156] ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']

# %% [markdown]
# #### For all tasks: replace... with your code

# %% [markdown]
# ---
#
# Task: Skip-gram
# -------
#
# ---

# %% [markdown]
# ### Step 3: Generate batch for the skip-gram model.

# %%
data_index = 0

def generate_skipgram_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1    # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window    # target label at the center of the buffer
        targets_to_avoid = [skip_window]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

# %%
batch, labels = generate_skipgram_batch(batch_size=8, num_skips=2, skip_window=1)

# %%
for i in range(8):
    print(batch[i], reverse_dictionary[batch[i]],
                '->', labels[i, 0], reverse_dictionary[labels[i, 0]])
# Out:
# 3084 originated -> 5237 anarchism
# 3084 originated -> 12 as
# 12 as -> 6 a
# 12 as -> 3084 originated
# 6 a -> 195 term
# 6 a -> 12 as
# 195 term -> 6 a
# 195 term -> 2 of

# %% [markdown]
# ### Step 4: Build skip-gram model.

# %%
class SkipgramModel(object):
    def __init__(self, 
                 vocabulary_size=50000, batch_size=128, embedding_size=128, 
                 skip_window=1, num_skips=2, valid_size=16, valid_window=100, num_sampled=64):
        # do not change this
        self.vocabulary_size = vocabulary_size
        
        self.batch_size = batch_size
        self.embedding_size = embedding_size    # Dimension of the embedding vector.
        self.skip_window = skip_window          # How many words to consider left and right.
        self.num_skips = num_skips              # How many times to reuse an input to generate a label.

        # We pick a random validation set to sample nearest neighbors. Here we limit the
        # validation samples to the words that have a low numeric ID, which by
        # construction are also the most frequent.
        self.valid_size = valid_size            # Random set of words to evaluate similarity on.
        self.valid_window = valid_window        # Only pick dev samples in the head of the distribution.
        self.valid_examples = np.random.choice(self.valid_window, self.valid_size, replace=False)
        self.num_sampled = num_sampled          # Number of negative examples to sample.
        
        self.build_model()
    
    
    def build_model(self):
        self.graph = tf.Graph()

        with self.graph.as_default():
            # Input data.
            self.train_inputs = ...  # placeholder for batch
            self.train_labels = ...  # placeholder for labels
            self.valid_dataset = ... # placeholder for valid examples

            # Ops and variables pinned to the CPU because of missing GPU implementation
            with tf.device('/cpu:0'):
                # Look up embeddings for inputs.
                embeddings = ...     # variable, vocab -> embedding size
                embed = ...          # embedding_lookup

                # Construct the variables for the NCE loss (noise contrastive estimation)
                nce_weights = ...    # variable, weights matrix
                nce_biases = ...     # variable, bias vector

            # Compute the average NCE loss for the batch.
            # tf.nce_loss automatically draws a new sample of the negative labels each
            # time we evaluate the loss.
            self.loss = tf.reduce_mean(
                    tf.nn.nce_loss(nce_weights, nce_biases, embed, 
                                   self.train_labels, 
                                   self.num_sampled, self.vocabulary_size))

            # Construct the Adagrad optimizer using a learning rate of 1.0.
            self.optimizer = tf.train.AdagradOptimizer(1.0).minimize(self.loss)

            # Compute the cosine similarity between minibatch examples and all embeddings.
            norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
            self.normalized_embeddings = embeddings / norm
            
            valid_embeddings = tf.nn.embedding_lookup(
                    self.normalized_embeddings, self.valid_dataset)
            self.similarity = tf.matmul(
                    valid_embeddings, self.normalized_embeddings, transpose_b=True)
    
    
    def train(self, num_steps, verbose=True):
        with tf.Session(graph=self.graph) as session:
            # We must initialize all variables before we use them.
            tf.initialize_all_variables().run()
            if verbose:
                print("Initialized")

            average_loss = 0
            for step in xrange(num_steps):
                
                # your_code_here, generate batch
                ...
                
                # and feed it to model
                feed_dict = {self.train_inputs: ..., 
                             self.train_labels: ...}
                # your_code_here

                _, loss_val = session.run([self.optimizer, self.loss], 
                                          feed_dict=feed_dict)
                average_loss += loss_val

                if verbose and step % 2000 == 0:
                    if step > 0:
                        average_loss /= 2000
                    # The average loss is an estimate of the loss over the last 2000 batches.
                    print("Average loss at step ", step, ": ", average_loss)
                    average_loss = 0

                # Note that this is expensive (~20% slowdown if computed every 500 steps)
                if verbose and step % 10000 == 0:
                    sim = self.similarity.eval()
                    for i in xrange(self.valid_size):
                        valid_word = reverse_dictionary[self.valid_examples[i]]
                        top_k = 8    # number of nearest neighbors
                        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                        log_str = "Nearest to %s:" % valid_word
                        for k in xrange(top_k):
                            close_word = reverse_dictionary[nearest[k]]
                            log_str = "%s %s," % (log_str, close_word)
                        print(log_str)
            final_embeddings = self.normalized_embeddings.eval()
            return final_embeddings

# %% [markdown]
# ### Step 5: Train skip-gram model.

# %%
num_steps = 100001
data_index = 0

final_embeddings = SkipgramModel(vocabulary_size=50000, batch_size=128, embedding_size=128, 
                                 skip_window=1, num_skips=2, 
                                 valid_size=16, valid_window=100, num_sampled=64).train(num_steps)
# Out:
# Initialized
# Average loss at step  0 :  289.667236328
# Nearest to their: kites, reformists, rope, retard, reis, frits, midfielders, affluent,
# Nearest to its: mccarthyism, midlands, broadcast, inherits, trophic, jannaeus, agnetha, linked,
# Nearest to called: kimberly, monopoly, thera, atsc, sustainable, krugerrand, bingu, wolfenstein,
# Nearest to been: serpentine, fanbase, markschies, norwood, lipid, several, eighteenth, smyrna,
# Nearest to this: ibrahim, mentions, fidel, inflatable, incremental, archeological, nautical, agreeable,
# Nearest to united: herg, digraph, moseley, milosevic, dispatched, andronicus, playa, goyen,
# Nearest to however: responses, hideo, deletions, gilbertese, praetorius, carson, bitrate, obligated,
# Nearest to not: amputees, gladiators, irene, runic, mysticeti, savannah, blink, david,
# Nearest to eight: revisions, stalk, shemini, boltzmann, kanpur, confirmed, barrington, jurisdictional,
# Nearest to these: bushnell, bounces, virtually, sixty, leitch, ifad, snaps, glue,
# Nearest to states: screenings, halliday, curried, powders, shawnee, substance, consultative, ar,
# Nearest to he: feeble, unobstructed, ethidium, incheon, stormy, japonic, serb, reuel,
# Nearest to after: frazee, screenshots, laud, emerges, plethora, meteorological, blasted, archives,
# Nearest to state: kgf, universes, heal, fiesole, experiment, bishops, ane, drabble,
# Nearest to two: boundaries, isabelle, suspicions, multiplications, filking, jarrett, melancholic, quadrilateral,
# Nearest to into: instantaneously, speyer, valentinian, unrealistic, petsamo, coral, waste, priesthood,
# Average loss at step  2000 :  113.911632888
# Average loss at step  4000 :  52.7176548393
# Average loss at step  6000 :  33.1541466525
# Average loss at step  8000 :  23.202250295
# Average loss at step  10000 :  18.0805127482
# Nearest to their: the, rope, this, victoriae, derleth, influential, proceed, roles,
# Nearest to its: broadcast, mccarthyism, the, defend, linked, metaphysics, samples, tradition,
# Nearest to called: reginae, tissue, gland, monopoly, victoriae, branden, trail, sustainable,
# Nearest to been: alchemical, cells, several, victoriae, via, eighteenth, artists, pneumonia,
# Nearest to this: the, their, alpina, paranormal, samples, alexander, fidel, a,
# Nearest to united: newsgroup, moseley, vs, victoriae, spider, acquired, schemata, dispatched,
# Nearest to however: responses, and, kick, aol, asterism, gland, worried, reginae,
# Nearest to not: weld, gladiators, david, stop, that, savannah, email, reginae,
# Nearest to eight: nine, victoriae, three, cl, five, reginae, zero, archie,
# Nearest to these: firstly, model, virtually, collins, gap, ranges, beliefs, series,
# Nearest to states: archie, reginae, substance, ar, gland, correspondence, wiring, rd,
# Nearest to he: feeble, she, it, father, sergei, expanded, serial, dorothy,
# Nearest to after: digit, in, emerges, mass, archives, before, pure, einstein,
# Nearest to state: bishops, alpina, reginae, online, archie, experiment, amount, librivox,
# Nearest to two: one, reginae, boundaries, agave, archie, nine, UNK, victoriae,
# Nearest to into: waste, unrealistic, in, coral, composition, selfish, cup, priesthood,
# Average loss at step  12000 :  14.1151994156
# Average loss at step  14000 :  11.9674190013
# Average loss at step  16000 :  9.9178671267
# Average loss at step  18000 :  8.65736664677
# Average loss at step  20000 :  7.87888748574
# Nearest to their: his, the, a, this, victoriae, roles, rope, s,
# Nearest to its: the, his, broadcast, a, mccarthyism, defend, samples, metaphysics,
# Nearest to called: reginae, monopoly, tissue, alp, sustainable, gland, and, branden,
# Nearest to been: was, via, adder, several, is, be, cells, alchemical,
# Nearest to this: the, a, it, their, paranormal, alpina, that, fidel,
# Nearest to united: newsgroup, moseley, andronicus, vs, cockpit, simplification, victoriae, spider,
# Nearest to however: and, responses, hideo, but, msg, kick, worried, asterism,
# Nearest to not: also, often, irene, weld, that, it, tines, stop,
# Nearest to eight: nine, five, seven, zero, six, three, four, victoriae,
# Nearest to these: firstly, ranges, selections, ducas, mystical, judgment, collins, there,
# Nearest to states: archie, substance, reginae, yin, ar, correspondence, gland, stolen,
# Nearest to he: it, she, feeble, and, they, but, there, yin,
# Nearest to after: in, before, digit, chirac, akin, circ, confuse, if,
# Nearest to state: bishops, pyruvate, UNK, polarized, amount, homosexual, experiment, online,
# Nearest to two: one, three, four, five, six, zero, seven, nine,
# Nearest to into: in, as, by, waste, unrealistic, and, guinness, during,
# Average loss at step  22000 :  7.21258799279
# Average loss at step  24000 :  6.88238171136
# Average loss at step  26000 :  6.69171044254
# Average loss at step  28000 :  6.19362006044
# Average loss at step  30000 :  6.2058082689
# Nearest to their: his, the, its, a, this, victoriae, roles, her,
# Nearest to its: the, their, his, a, akita, broadcast, ramps, mccarthyism,
# Nearest to called: reginae, monopoly, or, tissue, alp, sustainable, gland, alpina,
# Nearest to been: was, be, via, is, baumgarten, adder, akita, ghats,
# Nearest to this: the, it, a, their, akita, tunings, that, which,
# Nearest to united: newsgroup, moseley, cockpit, andronicus, of, simplification, putin, digraph,
# Nearest to however: and, but, responses, hideo, msg, in, aosta, kick,
# Nearest to not: also, angiotensin, often, it, they, irene, tines, weld,
# Nearest to eight: five, nine, seven, six, four, three, zero, two,
# Nearest to these: firstly, ranges, many, selections, there, the, reuptake, bounces,
# Nearest to states: archie, substance, reginae, yin, trout, abitibi, correspondence, gland,
# Nearest to he: it, she, they, feeble, akita, there, who, basically,
# Nearest to after: in, before, digit, when, chirac, diab, from, if,
# Nearest to state: bishops, pyruvate, reginae, akita, human, amount, online, homosexual,
# Nearest to two: three, four, one, six, five, eight, seven, abitibi,
# Nearest to into: in, from, aorta, and, by, instantaneously, during, as,
# Average loss at step  32000 :  5.82128165996
# Average loss at step  34000 :  5.87006113434
# Average loss at step  36000 :  5.70783862638
# Average loss at step  38000 :  5.28097296214
# Average loss at step  40000 :  5.50827434313
# Nearest to their: his, its, the, this, her, victoriae, a, roles,
# Nearest to its: the, their, his, akita, broadcast, a, this, mccarthyism,
# Nearest to called: and, reginae, monopoly, UNK, sustainable, alp, tissue, gland,
# Nearest to been: was, be, via, is, baumgarten, by, akita, were,
# Nearest to this: the, it, that, which, akita, their, tunings, alpina,
# Nearest to united: cockpit, moseley, simplification, newsgroup, andronicus, digraph, of, putin,
# Nearest to however: but, and, responses, that, msg, hideo, four, before,
# Nearest to not: it, also, often, angiotensin, they, weld, amputees, to,
# Nearest to eight: nine, seven, six, five, four, zero, three, two,
# Nearest to these: many, firstly, there, some, which, vma, ranges, all,
# Nearest to states: archie, substance, yin, screenings, reginae, abitibi, trout, correspondence,
# Nearest to he: it, she, they, feeble, who, akita, there, basically,
# Nearest to after: before, in, digit, when, lemmy, if, chirac, diab,
# Nearest to state: bishops, pyruvate, amount, online, reginae, polarized, akita, dasyprocta,
# Nearest to two: three, four, six, one, five, seven, eight, abitibi,
# Nearest to into: in, from, aorta, during, instantaneously, by, guinness, waste,
# Average loss at step  42000 :  5.29677757514
# Average loss at step  44000 :  5.35012103426
# Average loss at step  46000 :  5.26142618704
# Average loss at step  48000 :  5.0467483319
# Average loss at step  50000 :  5.17336783481
# Nearest to their: his, its, the, her, batcave, a, victoriae, this,
# Nearest to its: their, the, his, akita, broadcast, this, ramps, a,
# Nearest to called: reginae, alp, and, sustainable, monopoly, UNK, or, alpina,
# Nearest to been: was, be, via, by, baumgarten, were, had, akita,
# Nearest to this: it, the, which, that, akita, tunings, prism, alpina,
# Nearest to united: moseley, cockpit, simplification, andronicus, newsgroup, digraph, champ, putin,
# Nearest to however: but, and, that, responses, msg, when, before, thibetanus,
# Nearest to not: also, they, often, it, angiotensin, generally, weld, tines,
# Nearest to eight: nine, seven, six, four, five, three, zero, one,
# Nearest to these: many, some, firstly, all, there, qing, which, vma,
# Nearest to states: screenings, archie, substance, yin, reginae, trout, abitibi, correspondence,
# Nearest to he: it, she, they, who, there, feeble, basically, akita,
# Nearest to after: before, when, in, digit, lemmy, if, from, chirac,
# Nearest to state: bishops, hazael, amount, pyruvate, polarized, online, human, reginae,
# Nearest to two: three, four, one, six, five, eight, seven, abitibi,
# Nearest to into: from, aorta, in, during, and, instantaneously, under, on,
# Average loss at step  52000 :  5.16057941818
# Average loss at step  54000 :  5.11051012754
# Average loss at step  56000 :  5.04339744473
# Average loss at step  58000 :  5.08667337775
# Average loss at step  60000 :  4.95255742031
# Nearest to their: his, its, the, her, victoriae, batcave, this, tunings,
# Nearest to its: their, the, his, leontopithecus, akita, her, michelob, ramps,
# Nearest to called: jogaila, reginae, alp, sustainable, alpina, strictly, busy, monopoly,
# Nearest to been: be, was, by, via, had, baumgarten, were, akita,
# Nearest to this: it, which, that, the, callithrix, akita, some, tunings,
# Nearest to united: simplification, moseley, cockpit, andronicus, digraph, newsgroup, champ, abakan,
# Nearest to however: but, and, that, callithrix, when, microcebus, msg, responses,
# Nearest to not: also, they, often, angiotensin, it, to, generally, tines,
# Nearest to eight: nine, six, seven, five, four, zero, three, callithrix,
# Nearest to these: many, some, all, firstly, there, bandanese, qing, callithrix,
# Nearest to states: microcebus, callithrix, pulau, yin, archie, reginae, screenings, trout,
# Nearest to he: it, she, they, who, there, feeble, basically, pulau,
# Nearest to after: before, when, in, if, digit, from, lemmy, chirac,
# Nearest to state: bishops, callithrix, biomes, hazael, pulau, pyruvate, amount, reginae,
# Nearest to two: three, four, five, one, six, seven, eight, abitibi,
# Nearest to into: from, in, aorta, under, during, with, instantaneously, on,
# Average loss at step  62000 :  4.78704365969
# Average loss at step  64000 :  4.77618025541
# Average loss at step  66000 :  4.95221716607
# Average loss at step  68000 :  4.9015027622
# Average loss at step  70000 :  4.76296299136
# Nearest to their: its, his, the, her, victoriae, batcave, glycemic, this,
# Nearest to its: their, the, his, her, leontopithecus, musket, akita, michelob,
# Nearest to called: jogaila, reginae, alp, and, alpina, UNK, sleeves, sustainable,
# Nearest to been: be, was, by, were, had, via, baumgarten, also,
# Nearest to this: which, it, the, that, callithrix, some, akita, tunings,
# Nearest to united: thaler, simplification, cockpit, moseley, digraph, abakan, newsgroup, andronicus,
# Nearest to however: but, that, when, callithrix, and, microcebus, msg, responses,
# Nearest to not: often, they, also, angiotensin, generally, it, tines, to,
# Nearest to eight: six, seven, nine, five, four, three, zero, callithrix,
# Nearest to these: many, some, all, firstly, which, there, bandanese, callithrix,
# Nearest to states: microcebus, callithrix, screenings, pulau, archie, reginae, yin, abitibi,
# Nearest to he: it, she, they, who, there, feeble, basically, akita,
# Nearest to after: before, when, in, if, digit, chirac, from, lemmy,
# Nearest to state: biomes, bishops, callithrix, pyruvate, pulau, reginae, online, human,
# Nearest to two: three, four, six, five, one, seven, eight, abitibi,
# Nearest to into: from, aorta, during, in, under, instantaneously, with, pda,
# Average loss at step  72000 :  4.790433622
# Average loss at step  74000 :  4.77559870571
# Average loss at step  76000 :  4.86578393173
# Average loss at step  78000 :  4.80682938623
# Average loss at step  80000 :  4.82635489535
# Nearest to their: its, his, her, the, victoriae, batcave, glycemic, this,
# Nearest to its: their, his, the, her, akita, victoriae, leontopithecus, michelob,
# Nearest to called: jogaila, reginae, alp, alpina, gland, trustworthy, sleeves, entirety,
# Nearest to been: be, was, by, were, had, via, baumgarten, become,
# Nearest to this: it, which, the, callithrix, that, akita, some, tunings,
# Nearest to united: cockpit, simplification, moseley, thaler, of, garnering, andronicus, digraph,
# Nearest to however: but, when, that, callithrix, msg, and, microcebus, thibetanus,
# Nearest to not: they, often, generally, also, it, angiotensin, tines, heliocentric,
# Nearest to eight: seven, six, nine, five, four, three, zero, callithrix,
# Nearest to these: many, some, all, which, firstly, there, bandanese, such,
# Nearest to states: microcebus, callithrix, screenings, archie, pulau, hbox, abitibi, trout,
# Nearest to he: it, she, they, who, there, feeble, basically, akita,
# Nearest to after: before, when, in, from, if, during, digit, chirac,
# Nearest to state: callithrix, bishops, biomes, iit, pulau, pyruvate, reginae, pontificia,
# Nearest to two: three, four, six, five, one, seven, eight, abitibi,
# Nearest to into: from, during, under, aorta, in, with, pda, on,
# Average loss at step  82000 :  4.80443791485
# Average loss at step  84000 :  4.77048869848
# Average loss at step  86000 :  4.74606268513
# Average loss at step  88000 :  4.69449089861
# Average loss at step  90000 :  4.75913591421
# Nearest to their: its, his, her, the, some, victoriae, batcave, glycemic,
# Nearest to its: their, his, the, her, victoriae, akita, leontopithecus, musket,
# Nearest to called: jogaila, reginae, alpina, UNK, alp, entirety, gland, pulau,
# Nearest to been: be, was, were, had, by, become, baumgarten, via,
# Nearest to this: which, it, the, some, callithrix, akita, tunings, that,
# Nearest to united: simplification, thaler, cockpit, moseley, garnering, abakan, andronicus, digraph,
# Nearest to however: but, when, that, and, callithrix, which, although, msg,
# Nearest to not: they, often, also, generally, angiotensin, it, tines, still,
# Nearest to eight: seven, six, five, nine, four, three, zero, callithrix,
# Nearest to these: many, some, all, which, there, firstly, such, several,
# Nearest to states: microcebus, tamias, callithrix, pulau, archie, screenings, hbox, abitibi,
# Nearest to he: she, it, they, who, there, feeble, but, basically,
# Nearest to after: before, when, in, from, during, if, digit, at,
# Nearest to state: bishops, biomes, callithrix, tamias, city, iit, pulau, pyruvate,
# Nearest to two: three, four, five, six, seven, eight, one, abitibi,
# Nearest to into: from, under, during, aorta, in, with, through, tracing,
# Average loss at step  92000 :  4.70003813016
# Average loss at step  94000 :  4.61855047989
# Average loss at step  96000 :  4.72235048723
# Average loss at step  98000 :  4.62580613017
# Average loss at step  100000 :  4.66448467541
# Nearest to their: its, his, her, the, some, victoriae, both, glycemic,
# Nearest to its: their, his, the, her, victoriae, akita, leontopithecus, musket,
# Nearest to called: jogaila, frud, reginae, alpina, entirety, and, alp, busy,
# Nearest to been: be, was, by, become, were, had, baumgarten, troppo,
# Nearest to this: which, it, the, some, that, callithrix, akita, tunings,
# Nearest to united: thaler, simplification, cockpit, garnering, moseley, abakan, andronicus, weightings,
# Nearest to however: but, and, that, when, callithrix, although, thibetanus, microsite,
# Nearest to not: they, often, generally, also, angiotensin, tines, still, be,
# Nearest to eight: seven, nine, six, five, four, zero, three, callithrix,
# Nearest to these: many, some, all, which, such, firstly, there, several,
# Nearest to states: microcebus, tamias, screenings, callithrix, trout, attribution, zip, pulau,
# Nearest to he: she, it, they, there, who, feeble, basically, pulau,
# Nearest to after: before, when, during, from, in, at, if, while,
# Nearest to state: bishops, biomes, callithrix, iit, city, tamias, national, reginae,
# Nearest to two: four, three, five, six, seven, eight, one, ssbn,
# Nearest to into: from, under, during, through, aorta, in, with, on,

# %% [markdown]
# ### Step 6: Visualize embeddings.

# %%
def plot_with_labels(low_dim_embs, labels, filename='tsne_skipgram.png'):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    plt.figure(figsize=(18, 18))    # in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i, :]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')

    plt.savefig(filename)

# %%
plot_only = 500

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
low_dim_embs = tsne.fit_transform(final_embeddings[1:plot_only+1, :])
labels = [reverse_dictionary[i] for i in xrange(plot_only)]
plot_with_labels(low_dim_embs, labels)

# %% [markdown]
# ---
#
# Task: CBOW
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# ### Step 7: Generate batch for the CBOW model.

# %%
data_index = 0
cbow_window = 2

def generate_cbow_batch(batch_size, cbow_window):
    global data_index 
    
    # your_code_here
    ...
    # your_code_here
    
    return batch, labels

# %%
batch, labels = generate_cbow_batch(batch_size=3, cbow_window=cbow_window)

# %%
print('data:', [reverse_dictionary[di] for di in data[:5]])

for i in range(3):
    print("word:", reverse_dictionary[labels[i, 0]])
    print("context:", [reverse_dictionary[batch[i, j]] for j in range(2*cbow_window)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term']
# word: anarchism
# context: ['UNK', 'UNK', 'originated', 'as']
# word: originated
# context: ['UNK', 'UNK', 'as', 'a']
# word: as
# context: ['UNK', 'originated', 'a', 'term']

# %% [markdown]
# ### Step 8: Build CBOW model.

# %%
class CbowModel(object):
    def __init__(self, 
                 vocabulary_size=50000, batch_size=128, embedding_size=128, 
                 cbow_window=2, 
                 valid_size=16, valid_window=100, num_sampled=64):
        # do not change this
        self.vocabulary_size = vocabulary_size
        
        self.batch_size = batch_size
        self.embedding_size = embedding_size    # Dimension of the embedding vector.
        self.cbow_window = cbow_window 
        
        self.valid_size = valid_size            # Random set of words to evaluate similarity on.
        self.valid_window = valid_window        # Only pick dev samples in the head of the distribution.
        self.valid_examples = np.random.choice(self.valid_window, self.valid_size, replace=False)
        self.num_sampled = num_sampled          # Number of negative examples to sample.
        
        self.build_model()
    
    
    def build_model(self):
        # your_code_here
        ...
        # your_code_here
    
    
    def train(self, num_steps, verbose=True):
        with tf.Session(graph=self.graph) as session:
            tf.initialize_all_variables().run()
            if verbose:
                print('Initialized')

            average_loss = 0
            for step in range(num_steps):
                # your_code_here
                ...
                # your_code_here
                
                if verbose and step % 2000 == 0:
                    if step > 0:
                        average_loss = average_loss / 2000
                    # The average loss is an estimate of the loss over the last 2000 batches.
                    print('Average loss at step %d: %f' % (step, average_loss))
                    average_loss = 0

                # note that this is expensive (~20% slowdown if computed every 500 steps)
                if verbose and step % 10000 == 0:
                    sim = self.similarity.eval()
                    for i in range(self.valid_size):
                        valid_word = reverse_dictionary[self.valid_examples[i]]
                        top_k = 8  # number of nearest neighbors
                        nearest = (-sim[i, :]).argsort()[1:top_k + 1]
                        log = 'Nearest to %s:' % valid_word
                        for k in range(top_k):
                            close_word = reverse_dictionary[nearest[k]]
                            log = '%s %s,' % (log, close_word)
                        print(log)

            final_embeddings = ...
            return final_embeddings

# %% [markdown]
# ### Step 9: Train CBOW model.

# %%
num_steps = 100001
data_index = 0

final_embeddings = CbowModel(vocabulary_size=50000, batch_size=128, embedding_size=128, 
                             cbow_window=2, 
                             valid_size=16, valid_window=100, num_sampled=64).train(num_steps)
# Out:
# Initialized
# Average loss at step 0: 288.502533
# Nearest to two: provincial, tetrahedron, pluto, kurtosis, irrational, http, pork, trent,
# Nearest to he: malaysia, absurd, surface, jigs, curtailed, adalbert, meridians, lazarus,
# Nearest to people: switchable, endurance, kellerman, anschluss, unconditional, gills, turbo, extras,
# Nearest to may: notwithstanding, roms, segmentation, starting, scorer, infernal, squeezing, alumnus,
# Nearest to it: sk, alligators, passengers, synapse, pulsars, protester, bor, grappelli,
# Nearest to or: rejoin, faunas, histidine, u, transfection, trans, signature, geraldine,
# Nearest to years: garrison, postulates, offline, heavier, soi, trs, hectic, sucked,
# Nearest to there: scientology, modality, pid, comprised, domini, neutrinos, analysing, verde,
# Nearest to would: girth, speaking, sympathy, adversaries, leaned, narbonne, druidism, monologue,
# Nearest to into: punished, solemnity, sabra, telecasts, presidium, gloucestershire, amplitude, publicize,
# Nearest to this: uan, dedicating, altaic, nothingness, monmouth, gahan, attach, chromatids,
# Nearest to they: manhood, bran, kryptonian, kleist, piccard, austerity, waters, tulsa,
# Nearest to b: vectorborne, reidel, stand, adenauer, dentist, essentially, hyperplasia, per,
# Nearest to more: aleutians, befriended, tailor, cowardly, pillaging, plugged, melrose, humphries,
# Nearest to about: scrat, fibrosis, mair, narratives, supervises, excuse, dial, tutte,
# Nearest to six: sith, interpolating, orthodox, desolate, insight, consumed, unneeded, dunraven,
# Average loss at step 2000: 102.271586
# Average loss at step 4000: 45.609923
# Average loss at step 6000: 27.612373
# Average loss at step 8000: 18.721775
# Average loss at step 10000: 13.639333
# Nearest to two: nine, one, apollodorus, gunpowder, vincent, three, zero, kangaroo,
# Nearest to he: it, philippa, ganglion, absurd, ltd, visual, anime, she,
# Nearest to people: leucine, algerian, usa, july, pyruvate, ito, austin, gland,
# Nearest to may: can, would, must, will, could, might, gestis, sang,
# Nearest to it: he, attended, property, justifiable, am, id, linked, edwin,
# Nearest to or: and, signature, ermine, energies, rejoin, leland, ceuta, gran,
# Nearest to years: postulates, berber, gst, aqua, ohio, golda, switzer, contexts,
# Nearest to there: accumulated, outsiders, it, these, abwehr, forest, location, justifiable,
# Nearest to would: can, could, may, will, might, must, should, stochastic,
# Nearest to into: since, disposition, literally, agassi, bays, over, cube, pages,
# Nearest to this: the, studies, switches, nt, gambler, abatement, abortion, it,
# Nearest to they: registered, these, we, kernel, menabrea, he, lover, films,
# Nearest to b: d, shrimp, amicus, samuel, lagi, athenians, cauchy, rick,
# Nearest to more: less, aleutians, other, imitation, rather, cans, transformed, antoninus,
# Nearest to about: thinning, rogers, days, until, vera, stems, excuse, births,
# Nearest to six: eight, four, zero, nine, three, seven, five, neo,
# Average loss at step 12000: 10.524593
# Average loss at step 14000: 8.778544
# Average loss at step 16000: 7.484650
# Average loss at step 18000: 6.378521
# Average loss at step 20000: 5.770025
# Nearest to two: one, three, nine, five, zero, six, eight, four,
# Nearest to he: it, she, they, ltd, ganglion, philippa, xv, facing,
# Nearest to people: leucine, wetland, gills, communities, albinus, falls, review, july,
# Nearest to may: can, would, will, must, could, might, should, cannot,
# Nearest to it: he, this, attended, edwin, property, am, kabul, gambler,
# Nearest to or: and, ermine, persians, gran, litt, nitrite, hindered, than,
# Nearest to years: postulates, days, berber, contexts, switzer, malting, gst, golda,
# Nearest to there: they, these, accumulated, winfield, sauce, driven, outsiders, stol,
# Nearest to would: could, can, may, will, must, might, should, does,
# Nearest to into: since, bays, during, musical, agassi, marital, disposition, lessened,
# Nearest to this: it, the, that, switches, a, relinquishing, disloyal, which,
# Nearest to they: we, he, these, registered, there, drivers, evaluated, jamaica,
# Nearest to b: d, jitter, directing, sundown, capitolina, samuel, o, penn,
# Nearest to more: less, most, waxes, imitation, rather, aleutians, druid, other,
# Nearest to about: thinning, narrator, publishing, barbarous, five, pp, supervisor, dedication,
# Nearest to six: eight, four, five, seven, three, nine, zero, gland,
# Average loss at step 22000: 5.377126
# Average loss at step 24000: 5.211921
# Average loss at step 26000: 4.916099
# Average loss at step 28000: 4.863015
# Average loss at step 30000: 4.713193
# Nearest to two: three, five, six, one, zero, nine, four, eight,
# Nearest to he: she, it, they, ltd, ganglion, later, already, crimean,
# Nearest to people: leucine, them, wetland, unfavourable, births, those, gills, catalogue,
# Nearest to may: can, would, could, will, must, might, should, cannot,
# Nearest to it: he, this, edwin, benguela, then, she, property, pupil,
# Nearest to or: and, than, persians, gran, ermine, ceuta, litt, wu,
# Nearest to years: days, postulates, months, malting, contexts, golda, td, switzer,
# Nearest to there: they, stol, these, winfield, wct, sauce, accumulated, amplifiers,
# Nearest to would: could, will, can, must, may, might, should, does,
# Nearest to into: lessened, since, musical, bays, during, agassi, from, in,
# Nearest to this: it, which, that, allusions, the, gambler, relinquishing, staged,
# Nearest to they: we, he, these, you, there, registered, evaluated, drivers,
# Nearest to b: d, directing, jitter, chaney, samuel, navigator, drones, sundown,
# Nearest to more: less, most, waxes, rather, other, imitation, very, druid,
# Nearest to about: narrator, publishing, thinning, dedication, pp, anteater, supervisor, barbarous,
# Nearest to six: eight, five, seven, four, three, zero, nine, two,
# Average loss at step 32000: 4.672691
# Average loss at step 34000: 4.416745
# Average loss at step 36000: 4.426994
# Average loss at step 38000: 4.401364
# Average loss at step 40000: 4.439972
# Nearest to two: three, six, five, nine, one, four, seven, eight,
# Nearest to he: she, it, they, already, ganglion, ltd, later, who,
# Nearest to people: those, births, them, unfavourable, setbacks, fethry, critically, communities,
# Nearest to may: can, would, must, might, will, could, should, cannot,
# Nearest to it: he, this, she, edwin, benguela, elbridge, abatement, profiles,
# Nearest to or: and, ceuta, wu, than, doubled, receipt, gran, congenital,
# Nearest to years: days, months, postulates, tamarin, contexts, primigenius, switzer, year,
# Nearest to there: they, stol, disapproval, winfield, these, reasonable, it, driven,
# Nearest to would: will, could, might, may, must, can, should, did,
# Nearest to into: musical, bays, lessened, from, during, since, asterism, deified,
# Nearest to this: it, which, allusions, that, estonian, stereoisomers, the, disloyal,
# Nearest to they: we, he, you, there, these, burned, scarborough, evaluated,
# Nearest to b: d, o, directing, samuel, navigator, sundown, rebels, drones,
# Nearest to more: less, most, very, waxes, rather, imitation, das, druid,
# Nearest to about: narrator, pp, publishing, dedication, thinning, anteater, amalthea, supervisor,
# Nearest to six: seven, four, five, eight, three, zero, nine, two,
# Average loss at step 42000: 4.432729
# Average loss at step 44000: 4.398139
# Average loss at step 46000: 4.328271
# Average loss at step 48000: 4.315253
# Average loss at step 50000: 4.244384
# Nearest to two: three, four, nine, five, six, one, eight, seven,
# Nearest to he: she, it, they, already, ganglion, carmilla, ltd, later,
# Nearest to people: those, births, critically, unfavourable, members, fethry, communities, them,
# Nearest to may: can, would, must, might, will, could, should, cannot,
# Nearest to it: he, she, this, edwin, profiles, elbridge, itself, climate,
# Nearest to or: and, than, ceuta, gran, wu, including, cheryl, ermine,
# Nearest to years: days, months, postulates, decades, tamarin, contexts, year, assay,
# Nearest to there: they, stol, disapproval, amplifiers, winfield, reasonable, it, corpus,
# Nearest to would: will, could, might, may, must, should, can, did,
# Nearest to into: musical, lessened, bays, asterism, from, through, formosa, soto,
# Nearest to this: which, it, the, allusions, another, that, any, itself,
# Nearest to they: we, he, you, there, these, burned, evaluated, drivers,
# Nearest to b: d, samuel, directing, disqualified, o, sundown, navigator, drones,
# Nearest to more: less, most, very, rather, waxes, das, imitation, druid,
# Nearest to about: pp, narrator, publishing, supervisor, dedication, useful, thinning, anteater,
# Nearest to six: seven, eight, five, four, three, nine, zero, cegep,
# Average loss at step 52000: 4.229221
# Average loss at step 54000: 4.256393
# Average loss at step 56000: 4.261509
# Average loss at step 58000: 4.093780
# Average loss at step 60000: 4.409777
# Nearest to two: three, four, five, nine, six, eight, seven, one,
# Nearest to he: she, it, already, they, ganglion, carmilla, later, who,
# Nearest to people: those, fethry, members, births, parties, communities, scientists, persons,
# Nearest to may: can, would, must, will, might, could, should, cannot,
# Nearest to it: he, this, she, itself, profiles, edwin, peasant, charity,
# Nearest to or: and, than, cheryl, wu, ceuta, contraction, doubled, persians,
# Nearest to years: days, months, postulates, decades, year, tamarin, hours, assay,
# Nearest to there: they, disapproval, stol, winfield, it, reasonable, longer, protesters,
# Nearest to would: will, could, might, may, must, can, should, did,
# Nearest to into: through, lessened, musical, bays, asterism, from, across, off,
# Nearest to this: which, it, the, another, any, itself, every, corsican,
# Nearest to they: we, you, he, these, there, burned, evaluated, scarborough,
# Nearest to b: d, samuel, cegep, directing, disqualified, o, rupee, capitolina,
# Nearest to more: less, most, very, rather, greater, waxes, reinstate, das,
# Nearest to about: narrator, pp, book, publishing, supervisor, freebase, useful, burr,
# Nearest to six: seven, eight, five, four, three, nine, zero, two,
# Average loss at step 62000: 4.457160
# Average loss at step 64000: 4.243901
# Average loss at step 66000: 4.105246
# Average loss at step 68000: 4.130318
# Average loss at step 70000: 4.133356
# Nearest to two: three, four, five, six, eight, nine, seven, zero,
# Nearest to he: she, it, they, already, who, ganglion, carmilla, honeycomb,
# Nearest to people: those, members, them, communities, jews, attainder, donors, fethry,
# Nearest to may: can, would, might, will, must, could, should, cannot,
# Nearest to it: he, she, this, itself, charity, am, mainly, edwin,
# Nearest to or: and, than, planet, wu, contraction, leland, cheryl, form,
# Nearest to years: days, months, decades, postulates, year, tamarin, hours, minutes,
# Nearest to there: they, longer, disapproval, stol, winfield, it, reasonable, amplifiers,
# Nearest to would: will, could, might, may, must, should, can, did,
# Nearest to into: through, from, lessened, musical, bays, across, within, asterism,
# Nearest to this: which, it, that, the, eris, another, disloyal, every,
# Nearest to they: we, he, you, there, she, these, scarborough, drivers,
# Nearest to b: d, samuel, disqualified, statewide, angelico, avar, eris, mitochondria,
# Nearest to more: less, most, very, rather, higher, greater, das, druid,
# Nearest to about: pp, narrator, book, burr, births, review, ballast, cannabis,
# Nearest to six: seven, eight, five, four, three, zero, nine, two,
# Average loss at step 72000: 4.119146
# Average loss at step 74000: 4.107284
# Average loss at step 76000: 3.993425
# Average loss at step 78000: 4.114595
# Average loss at step 80000: 4.148953
# Nearest to two: three, four, five, six, zero, nine, seven, eight,
# Nearest to he: she, it, they, already, who, carmilla, ganglion, donegal,
# Nearest to people: those, members, jews, births, scientists, things, setbacks, communities,
# Nearest to may: can, would, might, could, will, must, should, cannot,
# Nearest to it: he, she, this, itself, still, edwin, charity, abatement,
# Nearest to or: and, wu, than, cheryl, contraction, persians, bond, leland,
# Nearest to years: days, months, decades, postulates, year, minutes, hours, weeks,
# Nearest to there: they, stol, disapproval, longer, winfield, knitting, severing, disclosures,
# Nearest to would: will, could, might, must, may, should, can, did,
# Nearest to into: through, lessened, from, down, within, across, bays, asterism,
# Nearest to this: which, it, another, itself, allusions, corsican, that, disloyal,
# Nearest to they: we, you, he, she, these, there, drivers, loud,
# Nearest to b: d, samuel, mitochondria, angelico, disqualified, sundown, glibc, statewide,
# Nearest to more: less, most, very, rather, higher, waxes, greater, reinstate,
# Nearest to about: narrator, pp, burr, book, amalthea, ballast, births, cannabis,
# Nearest to six: seven, eight, four, five, three, nine, zero, two,
# Average loss at step 82000: 4.087642
# Average loss at step 84000: 3.996986
# Average loss at step 86000: 4.067241
# Average loss at step 88000: 4.072310
# Average loss at step 90000: 4.062313
# Nearest to two: three, four, five, nine, six, eight, seven, zero,
# Nearest to he: she, it, they, already, ganglion, previously, who, donegal,
# Nearest to people: jews, members, persons, those, men, things, births, fethry,
# Nearest to may: can, would, might, will, could, must, should, cannot,
# Nearest to it: he, she, this, itself, charity, abatement, moynihan, profiles,
# Nearest to or: and, wu, than, contraction, cheryl, bond, doubled, while,
# Nearest to years: days, months, decades, year, minutes, hours, weeks, postulates,
# Nearest to there: they, longer, disapproval, stol, it, amplifiers, severing, knitting,
# Nearest to would: will, could, might, must, may, should, can, cannot,
# Nearest to into: through, from, lessened, across, asterism, down, within, cu,
# Nearest to this: which, it, another, itself, allusions, that, corsican, what,
# Nearest to they: we, he, you, she, there, scarborough, burned, these,
# Nearest to b: d, samuel, sundown, mitochondria, categorized, paperback, dose, rttemberg,
# Nearest to more: less, most, very, rather, better, greater, higher, smaller,
# Nearest to about: narrator, births, pp, ballast, review, anteater, book, burr,
# Nearest to six: seven, four, eight, five, three, nine, zero, two,
# Average loss at step 92000: 4.047131
# Average loss at step 94000: 3.956277
# Average loss at step 96000: 4.049576
# Average loss at step 98000: 4.006927
# Average loss at step 100000: 3.799795
# Nearest to two: three, five, four, six, seven, nine, eight, zero,
# Nearest to he: she, it, they, already, previously, initially, ridinghood, ganglion,
# Nearest to people: jews, persons, members, men, person, speakers, things, setbacks,
# Nearest to may: can, might, could, would, should, must, will, cannot,
# Nearest to it: he, she, this, itself, there, charity, profiles, nonviolent,
# Nearest to or: and, than, contraction, while, persians, cheryl, wu, congenital,
# Nearest to years: days, months, decades, year, hours, minutes, weeks, postulates,
# Nearest to there: they, stol, longer, disapproval, it, knitting, whereabouts, amplifiers,
# Nearest to would: will, could, might, must, may, should, can, cannot,
# Nearest to into: through, lessened, across, within, beyond, down, from, asterism,
# Nearest to this: which, another, it, itself, corsican, allusions, what, eris,
# Nearest to they: we, you, he, she, there, drivers, scarborough, these,
# Nearest to b: d, samuel, statewide, angelico, avar, drones, disqualified, mode,
# Nearest to more: less, most, very, rather, better, greater, smaller, higher,
# Nearest to about: narrator, review, ballast, book, pp, savanna, burr, anteater,
# Nearest to six: seven, eight, four, five, three, nine, zero, two,

# %% [markdown]
# ### Step 10: Visualize embeddings.

# %%
def plot_with_labels(low_dim_embs, labels, filename='tsne_cbow.png'):
    assert low_dim_embs.shape[0] >= len(labels), "More labels than embeddings"
    plt.figure(figsize=(18, 18))    # in inches
    for i, label in enumerate(labels):
        x, y = low_dim_embs[i, :]
        plt.scatter(x, y)
        plt.annotate(label,
                     xy=(x, y),
                     xytext=(5, 2),
                     textcoords='offset points',
                     ha='right',
                     va='bottom')

    plt.savefig(filename)

# %%
plot_only = 500

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
low_dim_embs = tsne.fit_transform(final_embeddings[1:plot_only+1, :])
labels = [reverse_dictionary[i] for i in xrange(plot_only)]
plot_with_labels(low_dim_embs, labels)
